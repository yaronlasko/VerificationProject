# %%
import sys
sys.path.append("../../hw/base")

from verification_utils import CHCs, mk_int_array
import graphviz

# %%
from z3 import *
import z3
z3.set_param(proof=True)  # this is needed so that we can call `.proof()` later

# %%
stack = Array('stack', IntSort(), IntSort())
mem = Array('mem', IntSort(), IntSort())
sp = Int('sp')
r0 = Int('r0')
r1 = Int('r1')
state_vars = [stack, sp, r0, r1, mem]

a, b = input_vars = Ints('a b')

# %%
U = {i: Function(f"U{i}", *(v.sort() for v in [*input_vars, *state_vars]), BoolSort())
     for i in range(6)}

# %%
def _index_labels(instructions):
        labels = {}
        for idx, line in enumerate(instructions):
            if isinstance(line, str):
                line = line.strip()
                label = line[:-1] if line.endswith(':') else line
                labels[label] = idx + 1
        return labels

# %%
def create_chc(program, input_vars, preCondition, postCondition):
    sigma = [*input_vars, *state_vars]
    U = {i: Function(f"U{i}", *(v.sort() for v in sigma), BoolSort())
         for i in range(len(program) + 1)}
    labels = _index_labels(program)
    chc = []
    chc.append(Implies(preCondition, U[0](sigma)))
    for i in range(len(program)):
        instruction = program[i]
        match instruction[0]:
            case "PUSH":
                chc.append(Implies(
                    U[i](sigma),
                    U[i+1](*input_vars, Store(stack, sp, instruction[1]), sp + 1, r0, r1, mem)
                ))

            case "POP":
                if instruction[1] == 1:
                    v0 = Select(stack, sp - 1)
                    chc.append(Implies(
                        U[i](sigma),
                        U[i+1](*input_vars, stack, sp - 1, v0, r1, mem)
                    ))
                elif instruction[1] == 2:
                    v0 = Select(stack, sp - 2)
                    v1 = Select(stack, sp - 1)
                    chc.append(Implies(
                        U[i](sigma),
                        U[i+1](*input_vars, stack, sp - 2, v0, v1, mem)
                    ))

            case "ALU":
                match instruction[1]:
                    case "ADD":
                        v = Int(f"alu_addv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == r0 + r1),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "SUB":
                        v = Int(f"alu_subv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == r0 - r1),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "MUL":
                        v = Int(f"alu_mulv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == r0 * r1),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "NEG":
                        v = Int(f"alu_negv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == -r0),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "AND":
                        v = Int(f"alu_andv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == If(And(r0 != 0, r1 != 0), 1, 0)),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "OR":
                        v = Int(f"alu_orv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == If(Or(r0 != 0, r1 != 0), 1, 0)),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "NOT":
                        v = Int(f"alu_notv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == If(r0 == 0, 1, 0)),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "SHL":
                        v = Int(f"alu_shlv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == r0 << r1),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "SHR":
                        v = Int(f"alu_shrv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == r0 >> r1),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

                    case "LT":
                        v = Int(f"alu_ltv_{i}")
                        chc.append(Implies(
                            And(U[i](sigma), v == If(r0 < r1, 1, 0)),
                            U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                        ))

            case "STOR":
                chc.append(Implies(
                    U[i](sigma),
                    U[i+1](*input_vars, stack, sp, r0, r1, Store(mem, r1, r0))
                ))

            case "LOAD":
                v = Int(f"mem_load_{i}")
                chc.append(Implies(
                    And(U[i](sigma), v == Select(mem, r0)),
                    U[i+1](*input_vars, Store(stack, sp, v), sp + 1, r0, r1, mem)
                ))

            case "JMP":
                chc.append(Implies(
                    U[i](sigma),
                    U[labels[instruction[:-1]]](*input_vars, stack, sp, r0, r1, mem)
                ))

            case "JZ":
                chc.append(Implies(
                    And(U[i](sigma), r0 == 0),
                    U[labels[instruction[:-1]]](*input_vars, stack, sp, r0, r1, mem)
                ))

            case "JNZ":
                chc.append(Implies(
                    And(U[i](sigma), r0 != 0),
                    U[labels[instruction[:-1]]]](*input_vars, stack, sp, r0, r1, mem)
                ))

            case "RET":
                if instruction[1] == 0:
                    chc.append(Implies(
                        U[i](sigma),
                        U[r0](*input_vars, stack, sp, r0, r1, mem)
                    ))
                elif instruction[1] == 1:
                    chc.append(Implies(
                        U[i](sigma),
                        U[r0](*input_vars, Store(stack, sp, r1), sp + 1, r0, r1, mem)
                    ))

    chc.append(Implies(U[len(program)](sigma), postCondition))
    return CHCs(chc)

# %%
program = [ ("PUSH", 1)]
input_vars = []
preCondition = sp == 0
postCondition = And(Select(stack, 0) == 1, sp == 1)
chc = create_chc(program, input_vars, preCondition, postCondition)
chc
# Out:
# <table style="background: white; color: black"><tr><td style="text-align: left">sp = 0 &rArr; U0(stack, sp, r0, r1, mem)</td></tr><tr><td style="text-align: left">U0(stack, sp, r0, r1, mem) &rArr;
# U1(Store(stack, sp, 1), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U1(stack, sp, r0, r1, mem) &rArr; stack[0] = 1 &and; sp = 1</td></tr></table>

# %%
chc.solve()
# Out:
# [U1 = [else ->
#        Or(Exists(k!4,
#                  And(Var(2) == 1,
#                      Var(1) == Store(k!4, 0, 1))),
#           Exists(k!4,
#                  And(Var(1) == Store(k!4, 0, 1),
#                      Var(2) == 1)))],
#  U0 = [else -> Var(1) == 0]]

# %%
program = [("PUSH", 13), ("POP",2),("ALU","MUL"), ("POP",2),("ALU","ADD"),("POP",1)]
a, b = Ints('a b')
input_vars = [a, b]
preCondition = And(stack == mk_int_array([a,b]), sp == 2)
postCondition = And(stack[sp] == a + b * 13)
chc = create_chc(program, input_vars, preCondition, postCondition)
chc
# Out:
# <table style="background: white; color: black"><tr><td style="text-align: left">stack = Store(Store(K(Int, 0), 0, a), 1, b) &and; sp = 2 &rArr;
# U0(a, b, stack, sp, r0, r1, mem)</td></tr><tr><td style="text-align: left">U0(a, b, stack, sp, r0, r1, mem) &rArr;
# U1(a, b, Store(stack, sp, 13), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U1(a, b, stack, sp, r0, r1, mem) &rArr;
# U2(a, b, stack, sp - 2, stack[sp - 2], stack[sp - 1], mem)</td></tr><tr><td style="text-align: left">U2(a, b, stack, sp, r0, r1, mem) &and; alu_mulv_2 = r0&middot;r1 &rArr;
# U3(a, b, Store(stack, sp, alu_mulv_2), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U3(a, b, stack, sp, r0, r1, mem) &rArr;
# U4(a, b, stack, sp - 2, stack[sp - 2], stack[sp - 1], mem)</td></tr><tr><td style="text-align: left">U4(a, b, stack, sp, r0, r1, mem) &and; alu_addv_4 = r0 + r1 &rArr;
# U5(a, b, Store(stack, sp, alu_addv_4), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U5(a, b, stack, sp, r0, r1, mem) &rArr;
# U6(a, b, stack, sp - 1, stack[sp - 1], r1, mem)</td></tr><tr><td style="text-align: left">U6(a, b, stack, sp, r0, r1, mem) &rArr; stack[sp] = a + b&middot;13</td></tr></table>

# %%
s = chc.solve({
#    'xform.inline_eager': False,
#    'xform.inline_linear': False
})
s
# Out:
# [U4 = [else ->
#        And(Var(5) == Var(2)[1],
#            Var(2) ==
#            Store(Store(Store(K(Int, 0), 0, Var(0)), 2, 13),
#                  1,
#                  13*Var(1)),
#            Var(4) == Var(2)[0],
#            Var(3) == 0)],
#  U5 = [else ->
#        Or(And(Var(2) ==
#               Store(Store(Store(K(Int, 0), 2, 13),
#                           1,
#                           13*Var(1)),
#                     0,
#                     Var(0) + Var(5)),
#               Var(5) == 13*Var(1),
#               Var(3) == 1,
#               Var(4) == Var(0)),
#           And(Var(2) ==
#               Store(Store(Store(K(Int, 0), 2, 13),
#                           1,
#                           13*Var(1)),
#                     0,
#                     Var(4) + Var(5)),
#               Var(3) == 1,
#               Var(5) == 13*Var(1),
#               Var(4) == Var(0)))],
#  U3 = [else ->
#        Or(And(Var(2) ==
#               Store(Store(Store(K(Int, 0), 0, Var(0)),
#                           2,
#                           13),
#                     1,
#                     13*Var(1)),
#               Var(3) == 2,
#               Var(4) == Var(1),
#               Var(5) == 13),
#           And(Var(2) ==
#               Store(Store(Store(K(Int, 0), 0, Var(0)),
#                           2,
#                           13),
#                     1,
#                     Var(4)*Var(5)),
#               Var(3) == 2,
#               Var(5) == 13,
#               Var(4) == Var(1)))],
#  U0 = [else ->
#        And(Var(2) ==
#            Store(Store(K(Int, 0), 0, Var(0)), 1, Var(1)),
#            Var(3) == 2)],
#  U2 = [else ->
#        And(Var(5) == Var(2)[2],
#            Var(2) ==
#            Store(Store(Store(K(Int, 0), 0, Var(0)),
#                        1,
#                        Var(1)),
#                  2,
#                  13),
#            Var(4) == Var(2)[1],
#            Var(3) == 1)],
#  U6 = [else ->
#        Or(And(Var(4) == Var(2)[0],
#               Var(2) ==
#               Store(Store(Store(K(Int, 0), 2, 13),
#                           1,
#                           13*Var(1)),
#                     0,
#                     Var(0) + Var(5)),
#               Var(5) == 13*Var(1),
#               Var(3) == 0),
#           And(Var(5) == 13*Var(1),
#               Var(2) ==
#               Store(Store(Store(K(Int, 0), 2, 13),
#                           1,
#                           13*Var(1)),
#                     0,
#                     Var(0) + Var(5)),
#               Var(4) == Var(2)[0],
#               Var(3) == 0))],
#  U1 = [else ->
#        Or(And(Var(2) ==
#               Store(Store(Store(K(Int, 0), 0, Var(0)),
#                           1,
#                           Var(1)),
#                     2,
#                     13),
#               Var(3) == 3),
#           And(Var(3) == 3,
#               Var(2) ==
#               Store(Store(Store(K(Int, 0), 0, Var(0)),
#                           1,
#                           Var(1)),
#                     2,
#                     13)))]]

# %%
program = [
    ("PUSH", 0),      # 0: Push 0 to stack
    ("POP", 1),       # 1: r0 = 0
    ("JZ", 5),        # 2: if r0 == 0 → jump to 5
    ("PUSH", 999),    # 3: (should be skipped)
    ("JMP", 6),       # 4: jump to 6
    ("PUSH", 42),     # 5: target of JZ
    ("POP", 1)        # 6: r0 = 42
]

a, b = Ints("a b")  # unused input vars
input_vars = [a, b]

# Define initial state
pre = And(
    stack == mk_int_array([]),
    sp == 0
)

# Define postcondition: r0 should be 42
post = (r0 == 42)

# Generate CHCs
chc = create_chc(program, input_vars, pre, post)

# Solve
chc.solve()
# Out:
# [U7 = [else ->
#        Or(And(Var(4) == Var(2)[0],
#               Var(2) == Store(K(Int, 0), 0, 42),
#               Var(3) == 0),
#           And(Var(2) == Store(K(Int, 0), 0, 42),
#               Var(3) == 0,
#               Var(4) == 42))],
#  U4 = [else -> False],
#  U5 = [else ->
#        And(Var(2) == K(Int, 0), Var(3) == 0, Var(4) == 0)],
#  U3 = [else -> False],
#  U0 = [else -> And(Var(2) == K(Int, 0), Var(3) == 0)],
#  U2 = [else ->
#        Or(And(Var(2) == K(Int, 0), Var(3) == 0, Var(4) == 0),
#           And(Var(4) == Var(2)[0],
#               Var(2) == K(Int, 0),
#               Var(3) == 0))],
#  U6 = [else ->
#        Or(And(Var(2) == Store(K(Int, 0), 0, 42),
#               Var(3) == 1,
#               Var(4) == 0),
#           And(Var(3) == 1,
#               Var(4) == 0,
#               Var(2) == Store(K(Int, 0), 0, 42)))],
#  U1 = [else ->
#        Or(And(Var(2) == K(Int, 0), Var(3) == 1),
#           And(Var(3) == 1, Var(2) == K(Int, 0)))]]

# %%
program = [
    ("PUSH", 999),    # 0: value
    ("PUSH", 42),     # 1: address
    ("POP", 2),       # 2: r0 = 999, r1 = 42
    ("STOR",),        # 3: mem[42] = 999
    ("PUSH", 42),     # 4: push address again
    ("POP", 1),       # 5: r0 = 42
    ("LOAD",),        # 6: stack[sp] = mem[42]
    ("POP", 1)        # 7: r0 = mem[42] = 999
]
a, b = Ints("a b")  # unused inputs
input_vars = [a, b]

pre = And(stack == mk_int_array([]), sp == 0)
post = (r0 == 999)

chc = create_chc(program, input_vars, pre, post)
chc.solve()
# Out:
# [U7 = [else ->
#        Or(Exists(k!2,
#                  And(Var(3) ==
#                      Store(Store(K(Int, 0), 1, 42),
#                            0,
#                            Var(7)[42]),
#                      Var(7) == Store(k!2, 42, 999),
#                      Var(4) == 1,
#                      Var(5) == 42,
#                      Var(6) == 42)),
#           Exists([k!5, k!4],
#                  And(Var(5) == 1 + k!4,
#                      Exists(k!1,
#                             And(Var(9) ==
#                                 Store(k!1, 42, 999),
#                                 k!5 ==
#                                 Store(Store(K(Int, 0),
#                                         1,
#                                         42),
#                                       0,
#                                       42),
#                                 k!4 == 0,
#                                 Var(7) == 42,
#                                 Var(8) == 42)),
#                      Var(4) ==
#                      Store(k!5, k!4, Var(8)[Var(6)]))))],
#  U8 = [else ->
#        Or(Exists(k!3,
#                  And(Var(3) ==
#                      Store(Store(K(Int, 0), 1, 42),
#                            0,
#                            Var(7)[42]),
#                      Var(7) == Store(k!3, 42, 999),
#                      Var(5) == Var(3)[0],
#                      Var(4) == 0,
#                      Var(6) == 42)),
#           Exists([k!3, k!2],
#                  And(Exists(k!2,
#                             And(Var(5) ==
#                                 Store(Store(K(Int, 0),
#                                         1,
#                                         42),
#                                       0,
#                                       Var(9)[42]),
#                                 Var(9) ==
#                                 Store(k!2, 42, 999),
#                                 k!3 == 1,
#                                 k!2 == 42,
#                                 Var(8) == 42)),
#                      Var(5) == -1 + k!3,
#                      Var(6) == Var(4)[-1 + k!3])))],
#  U4 = [else ->
#        Or(Exists(k!1,
#                  And(Var(7) == Store(k!1, 42, 999),
#                      Var(3) ==
#                      Store(Store(K(Int, 0), 0, 999), 1, 42),
#                      Var(4) == 0,
#                      Var(5) == 999,
#                      Var(6) == 42)),
#           Exists(k!0,
#                  And(Var(3) ==
#                      Store(Store(K(Int, 0), 0, 999), 1, 42),
#                      Var(4) == 0,
#                      Var(5) == 999,
#                      Var(6) == 42,
#                      Var(7) == Store(k!0, Var(6), Var(5)))))],
#  U5 = [else ->
#        Or(Exists(k!1,
#                  And(Var(7) == Store(k!1, 42, 999),
#                      Var(3) ==
#                      Store(Store(K(Int, 0), 1, 42), 0, 42),
#                      Var(4) == 1,
#                      Var(5) == 999,
#                      Var(6) == 42)),
#           Exists([k!4, k!3],
#                  And(Exists(k!1,
#                             And(Var(9) ==
#                                 Store(k!1, 42, 999),
#                                 k!4 ==
#                                 Store(Store(K(Int, 0),
#                                         0,
#                                         999),
#                                       1,
#                                       42),
#                                 k!3 == 0,
#                                 Var(7) == 999,
#                                 Var(8) == 42)),
#                      Var(4) == Store(k!4, k!3, 42),
#                      Var(5) == 1 + k!3)))],
#  U3 = [else ->
#        Or(And(Var(2) ==
#               Store(Store(K(Int, 0), 0, 999), 1, 42),
#               Var(3) == 0,
#               Var(4) == 999,
#               Var(5) == 42),
#           And(Var(4) == Var(2)[0],
#               Var(2) ==
#               Store(Store(K(Int, 0), 0, 999), 1, 42),
#               Var(5) == Var(2)[1],
#               Var(3) == 0))],
#  U0 = [else -> And(Var(2) == K(Int, 0), Var(3) == 0)],
#  U2 = [else ->
#        Or(And(Var(2) ==
#               Store(Store(K(Int, 0), 0, 999), 1, 42),
#               Var(3) == 2),
#           And(Var(3) == 2,
#               Var(2) ==
#               Store(Store(K(Int, 0), 0, 999), 1, 42)))],
#  U6 = [else ->
#        Or(Exists(k!1,
#                  And(Var(7) == Store(k!1, 42, 999),
#                      Var(3) ==
#                      Store(Store(K(Int, 0), 1, 42), 0, 42),
#                      Var(4) == 0,
#                      Var(5) == 42,
#                      Var(6) == 42)),
#           Exists([k!3, k!2],
#                  And(Exists(k!1,
#                             And(Var(9) ==
#                                 Store(k!1, 42, 999),
#                                 Var(5) ==
#                                 Store(Store(K(Int, 0),
#                                         1,
#                                         42),
#                                       0,
#                                       42),
#                                 k!3 == 1,
#                                 k!2 == 999,
#                                 Var(8) == 42)),
#                      Var(5) == -1 + k!3,
#                      Var(6) == Var(4)[-1 + k!3])))],
#  U1 = [else ->
#        Or(And(Var(2) == Store(K(Int, 0), 0, 999),
#               Var(3) == 1),
#           And(Var(3) == 1,
#               Var(2) == Store(K(Int, 0), 0, 999)))]]

# %%
# create_chc - test 2:
# POP
program = [("PUSH", 1), ("PUSH", 2), ("PUSH", 3),("POP",1), ("PUSH", 4), ("POP", 2)]
a, b = Int("a"), Int("b")
input_vars = [a, b]
preCondition = And(a >= 0, b >= 0)
postCondition = And(a >= 0, b >= 0)
chc = create_chc(program, input_vars, preCondition, postCondition)
chc
# Out:
# <table style="background: white; color: black"><tr><td style="text-align: left">a &ge; 0 &and; b &ge; 0 &rArr; U0(a, b, stack, sp, r0, r1, mem)</td></tr><tr><td style="text-align: left">U0(a, b, stack, sp, r0, r1, mem) &rArr;
# U1(a, b, Store(stack, sp, 1), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U1(a, b, stack, sp, r0, r1, mem) &rArr;
# U2(a, b, Store(stack, sp, 2), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U2(a, b, stack, sp, r0, r1, mem) &rArr;
# U3(a, b, Store(stack, sp, 3), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U3(a, b, stack, sp, r0, r1, mem) &rArr;
# U4(a, b, stack, sp - 1, stack[sp], r1, mem)</td></tr><tr><td style="text-align: left">U4(a, b, stack, sp, r0, r1, mem) &rArr;
# U5(a, b, Store(stack, sp, 4), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U5(a, b, stack, sp, r0, r1, mem) &rArr; a &ge; 0 &and; b &ge; 0</td></tr></table>

# %%
# create_chc - test 3:
# ALU \ ADD, SUB
program = [("PUSH", 1), ("PUSH", 2), ("ALU", "ADD"), ("ALU", "SUB"), ("PUSH", 44)]
a, b = Int("a"), Int("b")
input_vars = [a, b]
preCondition = And(a >= 0, b >= 0)
postCondition = And(a >= 0, b >= 0)
chc = create_chc(program, input_vars, preCondition, postCondition)
chc
# Out:
# <table style="background: white; color: black"><tr><td style="text-align: left">stack = Store(Store(K(Int, 0), 0, a), 1, b) &and; sp = 2 &rArr;
# U0(a, b, stack, sp, r0, r1)</td></tr><tr><td style="text-align: left">U0(a, b, stack, sp, r0, r1) &rArr;
# U1(a, b, Store(stack, sp, 1), sp + 1, r0, r1)</td></tr><tr><td style="text-align: left">U1(a, b, stack, sp, r0, r1) &rArr;
# U2(a, b, Store(stack, sp, 2), sp + 1, r0, r1)</td></tr><tr><td style="text-align: left">U2(a, b, stack, sp, r0, r1) &rArr;
# U3(a, b, Store(stack, sp + 1, r0 + r1), sp + 1, r0, r1)</td></tr><tr><td style="text-align: left">U3(a, b, stack, sp, r0, r1) &rArr;
# U4(a, b, Store(stack, sp + 1, r0 - r1), sp + 1, r0, r1)</td></tr></table>

# %%
program = [("PUSH", 13), ("POP",2),("ALU","MUL"), ("POP",2),("ALU","ADD"),("POP",1)]
a, b = Int("a"), Int("b")
input_vars = [a, b]
preCondition = And(stack == mk_int_array([a,b]), sp == 2)
postCondition = (stack[sp] == a + b * 13)
chc = create_chc(program, input_vars, preCondition, postCondition)
chc
# Out:
# <table style="background: white; color: black"><tr><td style="text-align: left">stack = Store(Store(K(Int, 0), 0, a), 1, b) &and; sp = 2 &rArr;
# U0(a, b, stack, sp, r0, r1, mem)</td></tr><tr><td style="text-align: left">U0(a, b, stack, sp, r0, r1, mem) &rArr;
# U1(a, b, Store(stack, sp, 13), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U1(a, b, stack, sp, r0, r1, mem) &rArr;
# U2(a, b, stack, sp - 2, stack[sp - 2], stack[sp - 1], mem)</td></tr><tr><td style="text-align: left">U2(a, b, stack, sp, r0, r1, mem) &rArr;
# U3(a, b, Store(stack, sp + 1, r0&middot;r1), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U3(a, b, stack, sp, r0, r1, mem) &rArr;
# U4(a, b, stack, sp - 2, stack[sp - 2], stack[sp - 1], mem)</td></tr><tr><td style="text-align: left">U4(a, b, stack, sp, r0, r1, mem) &rArr;
# U5(a, b, Store(stack, sp + 1, r0 + r1), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U5(a, b, stack, sp, r0, r1, mem) &rArr; stack[sp] = a + b&middot;13</td></tr></table>

# %%
s = chc.create_solver()
(res := s.check())
# Out:
# unsat

# %%
program = [("PUSH", 13), ("PUSH", 3), ("PUSH",5), ("JMP",1), ("POP",2), ("ALU","ADD"), ("POP",1)]
a, b = Int("a"), Int("b")
input_vars = [a, b]
preCondition = And(stack == mk_int_array([a,b]), sp == 2)
postCondition = (stack[sp] == a + b * 13)
chc = create_chc(program, input_vars, preCondition, postCondition)
chc
# Out:
# <table style="background: white; color: black"><tr><td style="text-align: left">stack = Store(Store(K(Int, 0), 0, a), 1, b) &and; sp = 2 &rArr;
# U0(a, b, stack, sp, r0, r1, mem)</td></tr><tr><td style="text-align: left">U0(a, b, stack, sp, r0, r1, mem) &rArr;
# U1(a, b, Store(stack, sp, 13), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U1(a, b, stack, sp, r0, r1, mem) &rArr;
# U2(a, b, Store(stack, sp, 3), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U2(a, b, stack, sp, r0, r1, mem) &rArr;
# U3(a, b, Store(stack, sp, 5), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U3(a, b, stack, sp, r0, r1, mem) &rArr;
# U1(a, b, stack, sp, r0, r1, mem)</td></tr><tr><td style="text-align: left">U4(a, b, stack, sp, r0, r1, mem) &rArr;
# U5(a, b, stack, sp - 2, stack[sp - 2], stack[sp - 1], mem)</td></tr><tr><td style="text-align: left">U5(a, b, stack, sp, r0, r1, mem) &rArr;
# U6(a, b, Store(stack, sp + 1, r0 + r1), sp + 1, r0, r1, mem)</td></tr><tr><td style="text-align: left">U6(a, b, stack, sp, r0, r1, mem) &rArr; stack[sp] = a + b&middot;13</td></tr></table>
